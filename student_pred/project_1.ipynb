# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
df=pd.read_csv("updated_dataset.csv")
df.head(10)
# Out:
#    ID No Prog Code  Gender   YoG  CGPA  CGPA100  CGPA200  CGPA300  CGPA400  \
# 0  42308       ICE  Female  2010  3.23     2.88     3.48     2.62     2.90
# 1  70978       BCH  Female  2010  3.58     3.25     4.26     3.37     3.47
# 2  31602       BCH    Male  2010  2.21     1.78     1.98     1.49     2.51
# 3  63847       BCH    Male  2010  2.70     2.67     2.44     2.00     2.35
# 4  30158       BCH  Female  2010  3.88     3.61     3.69     3.63     4.58
# 5  51740       BCH    Male  2010  2.97     2.66     2.98     3.28     3.07
# 6  76075       BCH    Male  2010  3.34     3.68     3.00     3.44     3.28
# 7  60888       BCH  Female  2010  2.56     2.30     2.50     2.29     2.77
# 8  43378       BCH    Male  2010  3.76     3.30     3.64     3.88     4.37
# 9  80307       BCH  Female  2010  3.96     3.94     3.89     3.81     4.17
#
#    SGPA  attendance  study_hours
# 0  3.13       80.62          4.9
# 1  3.02       95.98          6.6
# 2  2.19       63.12          0.9
# ...

# %%
df.columns
# Out:
# Index(['ID No', 'Prog Code', 'Gender', 'YoG', 'CGPA', 'CGPA100', 'CGPA200',
#        'CGPA300', 'CGPA400', 'SGPA', 'attendance', 'study_hours'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ID No          0
# Prog Code      0
# Gender         0
# YoG            0
# CGPA           0
# CGPA100        0
# CGPA200        0
# CGPA300        0
# CGPA400        0
# SGPA           0
# attendance     0
# study_hours    0
# dtype: int64

# %%
df["ID No"].duplicated().sum()
# Out:
# np.int64(72)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3046 entries, 0 to 3045
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID No        3046 non-null   int64
#  1   Prog Code    3046 non-null   object
#  2   Gender       3046 non-null   object
#  3   YoG          3046 non-null   int64
#  4   CGPA         3046 non-null   float64
#  5   CGPA100      3046 non-null   float64
#  6   CGPA200      3046 non-null   float64
#  7   CGPA300      3046 non-null   float64
#  8   CGPA400      3046 non-null   float64
#  9   SGPA         3046 non-null   float64
#  10  attendance   3046 non-null   float64
#  11  study_hours  3046 non-null   float64
# dtypes: float64(8), int64(2), object(2)
# memory usage: 285.7+ KB

# %%
df.describe()
# Out:
#               ID No          YoG         CGPA      CGPA100      CGPA200  \
# count   3046.000000  3046.000000  3046.000000  3046.000000  3046.000000
# mean   61082.817466  2012.183848     3.494813     3.636106     3.321687
# std    21256.532751     1.329104     0.691614     0.679256     0.782473
# min    23462.000000  2010.000000     1.520000     1.570000     1.170000
# 25%    42654.250000  2011.000000     3.000000     3.180000     2.760000
# 50%    61759.000000  2012.000000     3.560000     3.690000     3.340000
# 75%    79236.250000  2013.000000     4.010000     4.150000     3.920000
# max    97563.000000  2014.000000     4.990000     5.000000     5.000000
#
#            CGPA300      CGPA400         SGPA   attendance  study_hours
# count  3046.000000  3046.000000  3046.000000  3046.000000  3046.000000
# mean      3.418578     3.532508     3.119645    84.661855     4.585227
# std       0.858518     0.802228     0.616151    10.500314     2.087130
# ...

# %%
print(df[df["ID No"].duplicated(keep=False)])
# Out:
#       ID No Prog Code  Gender   YoG  CGPA  CGPA100  CGPA200  CGPA300  CGPA400  \
# 6     76075       BCH    Male  2010  3.34     3.68     3.00     3.44     3.28
# 10    82483       BCH  Female  2010  3.99     3.83     4.06     3.56     4.40
# 21    89501       BCH  Female  2011  4.40     4.04     4.38     4.52     4.73
# 27    47144       BCH  Female  2011  4.05     3.66     4.17     4.03     4.37
# 47    50580       BCH    Male  2011  3.31     3.28     3.14     3.42     3.45
# ...     ...       ...     ...   ...   ...      ...      ...      ...      ...
# 2914  84084      PHYE    Male  2013  2.16     3.13     1.86     2.03     1.91
# 2919  84084      PHYE  Female  2012  2.52     1.98     2.78     2.94     2.37
# 2953  36454      PHYE  Female  2013  4.47     4.31     4.24     4.86     4.61
# 2976  67113      PHYE  Female  2014  4.30     3.84     4.08     4.24     4.91
# 3010  81024      PHYG    Male  2011  2.84     2.90     2.57     3.03     2.93
#
# ...

# %%
df["ID No"].value_counts()
df[df['ID No']==39695]
# Out:
#       ID No Prog Code  Gender   YoG  CGPA  CGPA100  CGPA200  CGPA300  CGPA400  \
# 658   39695       CHM    Male  2011  4.14     3.86     4.13     4.23     4.40
# 1604  39695       CEN  Female  2010  4.78     4.93     4.88     4.74     4.72
# 1908  39695       EEE    Male  2011  2.90     3.41     3.08     2.45     3.03
#
#       SGPA  attendance  study_hours
# 658   3.75       92.90          7.1
# 1604  4.10       91.59          6.6
# 1908  3.30       67.18          2.6

# %%
df.drop(columns=['ID No','Prog Code','YoG','CGPA','SGPA'],inplace=True)

# %%
df.head(5)
# Out:
#    Gender  CGPA100  CGPA200  CGPA300  CGPA400  attendance  study_hours
# 0  Female     2.88     3.48     2.62     2.90       80.62          4.9
# 1  Female     3.25     4.26     3.37     3.47       95.98          6.6
# 2    Male     1.78     1.98     1.49     2.51       63.12          0.9
# 3    Male     2.67     2.44     2.00     2.35       61.16          2.7
# 4  Female     3.61     3.69     3.63     4.58       94.02          7.0

# %%
from sklearn.model_selection import train_test_split
def traintest(x,y):
  x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
  return x_train,x_test,y_train,y_test

# %%
def year_to_prdict(year):
  if year>=2 and year<=4:
    if year==2:
      x=df.drop(columns=['CGPA200','CGPA300','CGPA400'])
      y=df['CGPA200']
      lis=["CGPA100","attendance",	"study_hours"]
    elif(year==3):
      x=df.drop(columns=['CGPA300','CGPA400'])
      y=df['CGPA300']
      lis=["CGPA100",	"CGPA200","attendance",	"study_hours"]
    else:
      x=df.drop(columns=['CGPA400'])
      y=df['CGPA400']
      lis=["CGPA100",	"CGPA200",	"CGPA300",	"attendance",	"study_hours"]

  return x,y,lis

# %%
x,y,data=year_to_prdict(4)

# %%
y
# Out:
# 0       2.90
# 1       3.47
# 2       2.51
# 3       2.35
# 4       4.58
#         ...
# 3041    4.28
# 3042    3.02
# 3043    3.82
# 3044    4.63
# 3045    4.14
# Name: CGPA400, Length: 3046, dtype: float64

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
preprocessing=make_column_transformer((OneHotEncoder(sparse_output=False,handle_unknown='ignore'),['Gender']),
                           (StandardScaler(),data),remainder='drop')

# %%
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import RidgeCV
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
pipe=make_pipeline(preprocessing,RidgeCV(alphas=[0.01,0.1,1,10,100]))
pipe_rf=make_pipeline(preprocessing,RandomForestRegressor())
pipe_xg=make_pipeline(preprocessing,XGBRegressor())

# %%
x_train,x_test,y_train,y_test=traintest(x,y)

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['Gender']),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   ['CGPA100', 'CGPA200',
#                                                    'CGPA300', 'attendance',
#                                                    'study_hours'])])),
#                 ('ridgecv', RidgeCV(alphas=[0.01, 0.1, 1, 10, 100]))])

# %%
pipe_rf.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['Gender']),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   ['CGPA100', 'CGPA200',
#                                                    'CGPA300', 'attendance',
#                                                    'study_hours'])])),
#                 ('randomforestregressor', RandomForestRegressor())])

# %%
pipe_xg.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['Gender']),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   ['CGPA100', 'CGPA200',
#                                                    'CGPA300', 'attendance',
#                                                    'study_hours'])])),
#                 ('xgbregressor',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None...
#                               feature_types=None, feature_weights=None,
# ...

# %%
from sklearn import set_config
set_config(display='diagram')

# %%
y_pred=pipe.predict(x_test)

# %%
y_pred_rf=pipe_rf.predict(x_test)

# %%
y_pred_xg=pipe_xg.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,root_mean_squared_error
r2=r2_score(y_test,y_pred)
print('r2 score : ',r2)
mae=mean_absolute_error(y_test,y_pred)
print('mean_absolute_error : ',mae)
rmse=root_mean_squared_error(y_test,y_pred)
print('root_mean_squared_error : ',rmse)
# Out:
# r2 score :  0.742407361829298
# mean_absolute_error :  0.3473934682698717
# root_mean_squared_error :  0.42464903941299353

# %%
from sklearn.metrics import r2_score,mean_absolute_error,root_mean_squared_error
r2=r2_score(y_test,y_pred_rf)
print('r2 score : ',r2)
mae=mean_absolute_error(y_test,y_pred_rf)
print('mean_absolute_error : ',mae)
rmse=root_mean_squared_error(y_test,y_pred_rf)
print('root_mean_squared_error : ',rmse)
# Out:
# r2 score :  0.7568633532037408
# mean_absolute_error :  0.33353000000000005
# root_mean_squared_error :  0.4125614396966713

# %%
from sklearn.metrics import r2_score,mean_absolute_error,root_mean_squared_error
r2=r2_score(y_test,y_pred_xg)
print('r2 score : ',r2)
mae=mean_absolute_error(y_test,y_pred_xg)
print('mean_absolute_error : ',mae)
rmse=root_mean_squared_error(y_test,y_pred_xg)
print('root_mean_squared_error : ',rmse)
# Out:
# r2 score :  0.7071892058416073
# mean_absolute_error :  0.3605642473971258
# root_mean_squared_error :  0.4527484412286756

# %%
from sklearn.model_selection import learning_curve
train_sizes,train_score,valid_score=learning_curve(pipe,x,y,train_sizes=np.linspace(0.1,1.0,10),cv=5,scoring='neg_root_mean_squared_error')
train_error=-train_score.mean(axis=1)
valid_error=-valid_score.mean(axis=1)
plt.plot(train_sizes,train_error,'r-+',linewidth=2,label='train')
plt.plot(train_sizes,valid_error,'b-',linewidth=2,label='valid')
plt.show()

# %%
from sklearn.model_selection import learning_curve
train_sizes,train_score,valid_score=learning_curve(pipe_xg,x,y,train_sizes=np.linspace(0.1,1.0,10),cv=5,scoring='neg_root_mean_squared_error')
train_error=-train_score.mean(axis=1)
valid_error=-valid_score.mean(axis=1)
plt.plot(train_sizes,train_error,'r-+',linewidth=2,label='train')
plt.plot(train_sizes,valid_error,'b-',linewidth=2,label='valid')
plt.show()

# %%
'''  Ridge CV
year 2 : r2 score :  0.6555959358661458
mean_absolute_error :  0.3701230846549862
root_mean_squared_error :  0.4586308344595292

year 3 : r2 score :  0.7411241239406251
mean_absolute_error :  0.36114319092225894
root_mean_squared_error :  0.452393980183484

year 4 : r2 score :  0.7424073618293611
mean_absolute_error :  0.3473934682697866
root_mean_squared_error :  0.4246490394129415

RANDOM FOREST
year 2:
r2 score :  0.6750770228112366
mean_absolute_error :  0.35080065573770486
root_mean_squared_error :  0.4454708880848977

year 3
r2 score :  0.7606339066916132
mean_absolute_error :  0.34210704918032786
root_mean_squared_error :  0.43501310688752176

year 4
r2 score :  0.7524628762737284
mean_absolute_error :  0.33857622950819677
root_mean_squared_error :  0.4162781278046261

XGBOOST
year 2
r2 score :  0.6355944549212793
mean_absolute_error :  0.3729409759709093
root_mean_squared_error :  0.4717605317325628

year 3
r2 score :  0.722891583888075
mean_absolute_error :  0.363205732040718
root_mean_squared_error :  0.4680539174949506

year 4
r2 score :  0.7071892058416073
mean_absolute_error :  0.3605642473971258
root_mean_squared_error :  0.4527484412286756
'''
# Out:
# '  Ridge CV\nyear 2 : r2 score :  0.6555959358661458\nmean_absolute_error :  0.3701230846549862\nroot_mean_squared_error :  0.4586308344595292\n\nyear 3 : r2 score :  0.7411241239406251\nmean_absolute_error :  0.36114319092225894\nroot_mean_squared_error :  0.452393980183484\n\nyear 4 : r2 score :  0.7424073618293611\nmean_absolute_error :  0.3473934682697866\nroot_mean_squared_error :  0.4246490394129415\n\nRANDOM FOREST\nyear 2:\nr2 score :  0.6750770228112366\nmean_absolute_error :  0.35080065573770486\nroot_mean_squared_error :  0.4454708880848977\n\nyear 3\nr2 score :  0.7606339066916132\nmean_absolute_error :  0.34210704918032786\nroot_mean_squared_error :  0.43501310688752176\n\nyear 4\nr2 score :  0.7524628762737284\nmean_absolute_error :  0.33857622950819677\nroot_mean_squared_error :  0.4162781278046261\n\nXGBOOST\nyear 2\nr2 score :  0.6355944549212793\nmean_absolute_error :  0.3729409759709093\nroot_mean_squared_error :  0.4717605317325628\n\nyear 3\nr2 score :  0.7228915
# ...

# %%
import seaborn as sns
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap="coolwarm",
            fmt=".2f",
            linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(y_test, y_pred, alpha=0.6)
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()],
         'r--', linewidth=2)
plt.xlabel("Actual CGPA")
plt.ylabel("Predicted CGPA")
plt.title("Actual vs Predicted")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(y_test, y_pred_rf, alpha=0.6)
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()],
         'r--', linewidth=2)
plt.xlabel("Actual CGPA")
plt.ylabel("Predicted CGPA")
plt.title("Actual vs Predicted")
plt.grid(True)
plt.show()

# %%
residuals = y_test - y_pred

plt.figure(figsize=(6,4))
plt.scatter(y_pred, residuals, alpha=0.6)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Predicted")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
coefficients = pipe_rf.named_steps['ridgecv'].coef_

feature_names = pipe_rf.named_steps['columntransformer'].get_feature_names_out()

importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Coefficient": coefficients
})

importance_df.sort_values(by="Coefficient", inplace=True)

plt.figure(figsize=(8,6))
plt.barh(importance_df["Feature"], importance_df["Coefficient"])
plt.title("Feature Importance")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[204], line 1
# ----> 1 coefficients = pipe_rf.named_steps['ridgecv'].coef_
#       3 feature_names = pipe_rf.named_steps['columntransformer'].get_feature_names_out()
#       5 importance_df = pd.DataFrame({
#       6     "Feature": feature_names,
#       7     "Coefficient": coefficients
#       8 })
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_bunch.py:42, in Bunch.__getitem__(self, key)
#      37 if key in self.__dict__.get("_deprecated_key_to_warnings", {}):
#      38     warnings.warn(
#      39         self._deprecated_key_to_warnings[key],
#      40         FutureWarning,
#      41     )
# ---> 42 return super().__getitem__(key)
#
# KeyError: 'ridgecv'

# %%
coefficients = pipe.named_steps['ridgecv'].coef_

feature_names = pipe.named_steps['columntransformer'].get_feature_names_out()

importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Coefficient": coefficients
})

importance_df.sort_values(by="Coefficient", inplace=True)

plt.figure(figsize=(8,6))
plt.barh(importance_df["Feature"], importance_df["Coefficient"])
plt.title("Feature Importance")
plt.show()

# %%
sdfvgbhnm,

# %%
import joblib
for year in[2,3,4]:
    x,y,data=year_to_prdict(year)
    preprocessing=make_column_transformer((OneHotEncoder(sparse_output=False,handle_unknown='ignore'),['Gender']),
                           (StandardScaler(),data),remainder='drop')
    pipe=make_pipeline(preprocessing,RidgeCV(alphas=[0.01,0.1,1,10,100]))
    x_train, x_test, y_train, y_test=traintest(x,y)
    pipe.fit(x_train,y_train)
    joblib.dump(pipe,f"model_year_{year}.pkl")

print("All models trained and saved")
# Out:
# All models trained and saved
